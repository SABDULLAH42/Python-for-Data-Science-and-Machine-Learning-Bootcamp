# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\USER\\Desktop\\UDEMY\\Python for Data Science and Machine Learning Bootcamp\\Pandas_Builtin_Data_Visualization'

# %%
import os

path = "C:\\Users\\USER\\Desktop\\UDEMY\\Python for Data Science and Machine Learning Bootcamp\\Pandas_Builtin_Data_Visualization"  # Example: "./" for the current directory
files = os.listdir(path)
print(files)
# Out:
# ['.ipynb_checkpoints', 'df1', 'df2', 'df3', 'Pandas_data_viz_01.ipynb', 'Untitled.ipynb', 'untitled.txt', 'untitled1.txt']

# %%
df3 = pd.read_csv('df3')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a', y='b',figsize=(12,3), s=50, c='red' )
plt.show()

# %%
df3['a'].hist(grid=False,color='b', bins=20)
sns.set_style(style='white')
plt.show()

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(grid=True,alpha=0.5, bins=20)
sns.set_style('darkgrid')
plt.show()

# %%
plt.style.use(

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3[['a', 'b']].plot.box()
plt.show()

# %%
df3['d'].plot.kde()
plt.show()

# %%
df3['d'].plot.kde(lw=5, ls='--', color='darkorange')
plt.show()

# %%
df3.loc[0:30].plot.area(alpha=0.4)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

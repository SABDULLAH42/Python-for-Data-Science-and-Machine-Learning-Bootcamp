# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df1 = pd.read_csv('df1')
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1 = pd.read_csv('df1', index_col=[0] )
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df1.iloc[[2], [1]]
# Out:
#                    B
# 2000-01-03 -0.482943

# %%
df1 = pd.read_csv('df1', index_col=0 )
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
sns.set_style('darkgrid')
plt.show()

# %%
df1['A'].plot(kind='hist', bins=30, grid=True )
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4, grid=True)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1.plot.line(y = 'B', figsize=(12,3), lw=1)  # no need to give x arguemnet it is optional
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A', y='B', c='C',cmap='coolwarm' )
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100 )
# Out:
# C:\Users\USER\anaconda3\envs\my_asad\Lib\site-packages\matplotlib\collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'] )
df
# Out:
#             a         b
# 0    0.043300  0.396424
# 1   -0.347717  0.778706
# 2   -0.811107 -0.194869
# 3   -1.872306 -0.906222
# 4    0.967902 -1.224324
# ..        ...       ...
# 995 -0.043759  1.508809
# 996  1.286501  0.011445
# 997  0.921847 -0.506043
# 998 -0.631850 -1.309684
# 999  1.396050  0.423282
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x= 'a', y='b' , C=None, gridsize= 25   )
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
import matplotlib

# %%
print(matplotlib.__version__)

# %%
dm= np.random.randn(2000, 5)
dm
# Out:
# array([[-0.95358171, -0.10630121, -0.18271574,  1.09854971, -1.62942649],
#        [-0.59848996,  0.05446746,  1.31736333,  0.82163295,  1.99243433],
#        [-0.55635598,  0.04198304,  0.5722437 , -0.39352212, -0.16203501],
#        ...,
#        [ 0.04652813,  0.14935692, -0.10342759,  2.1477315 ,  0.74620562],
#        [ 0.15326154,  0.43108112, -0.66589176, -0.17653787, -0.29815558],
#        [-0.95818695, -1.57283832,  0.26358866,  0.13798703, -0.81506048]],
#       shape=(2000, 5))

# %%
df2['a'].plot.kde()     # omly the 1 column
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.density()   # The whole column
# Out:
# <Axes: ylabel='Density'>

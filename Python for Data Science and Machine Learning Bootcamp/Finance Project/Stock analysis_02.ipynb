# %%
import pandas as pd
import yfinance as yf
import numpy as np
import seaborn as sns
import datetime
# %matplotlib inline

# %%
tickers = ["BAC","C","GS","JPM","MS","WFC"]

# %%
df = yf.download(tickers, start="2006-01-01", end="2016-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
df.head()
# Out:
# Price           Close                                                          \
# Ticker            BAC           C         GS        JPM         MS        WFC
# Date
# 2006-01-03  31.173685  324.013214  95.293129  24.241709  32.190910  18.778109
# 2006-01-04  30.842609  318.031158  93.976891  24.101791  32.212982  18.560308
# 2006-01-05  30.882326  319.608856  93.939911  24.174795  32.301315  18.539701
# 2006-01-06  30.835981  319.608856  95.270950  24.345121  32.334446  18.648609
# 2006-01-09  30.855846  318.096863  96.417076  24.740532  32.676727  18.645660
#
# Price            High                                    ...       Open  \
# Ticker            BAC           C         GS        JPM  ...         GS
# Date                                                     ...
# 2006-01-03  31.239898  324.604835  95.714622  24.344250  ...  93.688520
# 2006-01-04  31.279624  322.764164  95.322698  24.418120  ...  94.169150
# 2006-01-05  31.008135  320.660618  94.146956  24.217378  ...  93.170881
# 2006-01-06  31.061110  321.449459  95.574128  24.478953  ...  94.124804
# 2006-01-09  31.100841  320.397625  96.587147  24.770950  ...  95.019513
#
# Price                                          Volume                    \
# Ticker            JPM         MS        WFC       BAC        C       GS
# Date
# 2006-01-03  24.024567  31.561554  18.601512  16296700  1537600  6188700
# 2006-01-04  24.199123  32.406206  18.719245  17757900  1870960  4861600
# 2006-01-05  24.095712  32.323398  18.542644  14970700  1143160  3717400
# 2006-01-06  24.284288  32.444859  18.589743  12599800  1370210  4319600
# 2006-01-09  24.259958  32.367572  18.645660  15619400  1680740  4723500
#
# Price
# Ticker           JPM       MS       WFC
# Date
# 2006-01-03  12838600  5377000  11016400
# 2006-01-04  13491500  7977800  10870000
# 2006-01-05   8109400  5778000  10158000
# 2006-01-06   7966900  6889800   8403800
# 2006-01-09  16575200  4144500   5619600
#
# [5 rows x 30 columns]

# %%
df.xs(key = 'Close', axis=1)
# Out:
# Stock Info        BAC           C          GS        JPM         MS        WFC
# Date
# 2006-01-03  31.173685  324.013214   95.293129  24.241709  32.190910  18.778109
# 2006-01-04  30.842609  318.031158   93.976891  24.101791  32.212982  18.560308
# 2006-01-05  30.882326  319.608856   93.939911  24.174795  32.301315  18.539701
# 2006-01-06  30.835981  319.608856   95.270950  24.345121  32.334446  18.648609
# 2006-01-09  30.855846  318.096863   96.417076  24.740532  32.676727  18.645660
# ...               ...         ...         ...        ...        ...        ...
# 2015-12-24  14.103423   40.187351  150.992554  51.625504  24.987900  42.026825
# 2015-12-28  13.989092   39.935757  150.289139  51.454983  24.749409  41.919491
# 2015-12-29  14.111584   40.393208  151.869675  51.989838  25.041752  42.387138
# 2015-12-30  13.923758   39.874756  150.611862  51.617760  24.795572  42.080486
# 2015-12-31  13.744097   39.455421  149.138992  51.183681  24.472456  41.674164
#
# [2517 rows x 6 columns]

# %%
ticker1 = "BAC"
BAC = yf.download(ticker1, start="2006-01-01", end="2016-01-01")

ticker2 = "C"
C = yf.download(ticker2, start="2006-01-01", end="2016-01-01")

ticker3 = "GS"
GS = yf.download(ticker3, start="2006-01-01", end="2016-01-01")

ticker4 = "JPM"
JPM = yf.download(ticker4, start="2006-01-01", end="2016-01-01")

ticker5 = "MS"
MS = yf.download(ticker5, start="2006-01-01", end="2016-01-01")

ticker6 = "WFC"
WFC = yf.download(ticker6, start="2006-01-01", end="2016-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
ticker_stock = ["BAC","C","GS","JPM","MS","WFC"]

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis=1, keys=ticker_stock )

# %%
# bank_stocks.columns.names = ['Bank Ticker', 'Stock Info']

# %%
bank_stocks.head()
# Out:
#                   BAC                                                      C  \
# Price           Close       High        Low       Open    Volume       Close
# Ticker            BAC        BAC        BAC        BAC       BAC           C
# Date
# 2006-01-03  31.173685  31.239898  30.557892  31.067740  16296700  324.013214
# 2006-01-04  30.842609  31.279624  30.756530  31.120708  17757900  318.031158
# 2006-01-05  30.882326  31.008135  30.670441  30.842599  14970700  319.608856
# 2006-01-06  30.835981  31.061110  30.690309  30.988274  12599800  319.608856
# 2006-01-09  30.855846  31.100841  30.696934  30.935305  15619400  318.096863
#
#                                                          ...         MS  \
# Price             High         Low        Open   Volume  ...      Close
# Ticker               C           C           C        C  ...         MS
# Date                                                     ...
# 2006-01-03  324.604835  316.256363  322.106871  1537600  ...  32.190910
# 2006-01-04  322.764164  317.833958  321.186502  1870960  ...  32.212982
# 2006-01-05  320.660618  318.162654  318.425595  1143160  ...  32.301315
# 2006-01-06  321.449459  316.847933  321.317978  1370210  ...  32.334446
# 2006-01-09  320.397625  317.505242  319.477324  1680740  ...  32.676727
#
#                                                             WFC             \
# Price            High        Low       Open   Volume      Close       High
# Ticker             MS         MS         MS       MS        WFC        WFC
# Date
# 2006-01-03  32.290282  31.324168  31.561554  5377000  18.778109  18.822258
# 2006-01-04  32.726403  32.212982  32.406206  7977800  18.560308  18.731018
# 2006-01-05  32.345482  32.030805  32.323398  5778000  18.539701  18.575020
# 2006-01-06  32.489023  32.047372  32.444859  6889800  18.648609  18.704531
# 2006-01-09  32.731935  32.362050  32.367572  4144500  18.645660  18.733960
#
#
# Price             Low       Open    Volume
# Ticker            WFC        WFC       WFC
# Date
# 2006-01-03  18.363107  18.601512  11016400
# 2006-01-04  18.463180  18.719245  10870000
# 2006-01-05  18.430799  18.542644  10158000
# 2006-01-06  18.474956  18.589743   8403800
# 2006-01-09  18.575022  18.645660   5619600
#
# [5 rows x 30 columns]

# %%
bank_stocks.xs(key="Close", axis=1, level=1)
# Out:
#                    BAC           C          GS        JPM         MS  \
# Bank Ticker        BAC           C          GS        JPM         MS
# Date
# 2006-01-03
# Out:
#                    BAC           C          GS        JPM         MS  \
# Bank Ticker        BAC           C          GS        JPM         MS
# Date
# 2006-01-03   31.173685  324.013214   95.293129  24.241709  32.190910
# 2006-01-04   30.842609  318.031158   93.976891  24.101791  32.212982
# 2006-01-05   30.882326  319.608856   93.939911  24.174795  32.301315
# 2006-01-06   30.835981  319.608856   95.270950  24.345121  32.334446
# 2006-01-09   30.855846  318.096863   96.417076  24.740532  32.676727
# ...                ...         ...         ...        ...        ...
# 2015-12-24   14.103423   40.187351  150.992554  51.625504  24.987900
# 2015-12-28   13.989092   39.935757  150.289139  51.454983  24.749409
# 2015-12-29   14.111584   40.393208  151.869675  51.989838  25.041752
# 2015-12-30   13.923758   39.874756  150.611862  51.617760  24.795572
# 2015-12-31   13.744097   39.455421  149.138992  51.183681  24.472456
#
#                    WFC
# Bank Ticker        WFC
# Date
# 2006-01-03   18.778109
# 2006-01-04   18.560308
# 2006-01-05   18.539701
# 2006-01-06   18.648609
# 2006-01-09   18.645660
# ...                ...
# 2015-12-24   42.026825
# 2015-12-28   41.919491
# 2015-12-29   42.387138
# 2015-12-30   42.080486
# 2015-12-31   41.674164
#
# [2517 rows x 6 columns]

# %%
bank_stocks2['BAC']['Close']
# Out:
# Bank Ticker        BAC
# Date
# 2006-01-03   31.173685
# 2006-01-04   30.842609
# 2006-01-05   30.882326
# 2006-01-06   30.835981
# 2006-01-09   30.855846
# ...                ...
# 2015-12-24   14.103423
# 2015-12-28   13.989092
# 2015-12-29   14.111584
# 2015-12-30   13.923758
# 2015-12-31   13.744097
#
# [2517 rows x 1 columns]

# %%
for tick in ticker_stock:
    print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC Bank Ticker
# BAC    37.699574
# dtype: float64
# C Bank Ticker
# C    386.292755
# dtype: float64
# GS Bank Ticker
# GS    186.076096
# dtype: float64
# JPM Bank Ticker
# JPM    53.933922
# dtype: float64
# MS Bank Ticker
# MS    50.462799
# dtype: float64
# WFC Bank Ticker
# WFC    44.268097
# dtype: float64

# %%
#print(df.isna().sum())

# %%
#print(df.columns)

# %%
#print(df.isnull().sum())  #Some stocks may not have full historical data. You can check for missing values with:

# %%
df['Close']['BAC'].max()
# Out:
# 37.6995735168457

# %% [markdown]
# ### What is the max close price for each bank's stock throughout the time period

# %%
for tick in tickers:
    print(tick,  df['Close'][tick].max())
# Out:
# BAC 37.6995735168457
# C 386.2927551269531
# GS 186.0760955810547
# JPM 53.933921813964844
# MS 50.462799072265625
# WFC 44.268096923828125

# %% [markdown]
# ### Alternate way using.xs ie cross-section method

# %%
#df.columns.names = ('Bank Ticker', 'Stock Info')

# %%
df.xs(key = 'Close', axis=1)
# Out:
# Stock Info        BAC           C          GS        JPM         MS        WFC
# Date
# 2006-01-03  31.173685  324.013214   95.293129  24.241709  32.190910  18.778109
# 2006-01-04  30.842609  318.031158   93.976891  24.101791  32.212982  18.560308
# 2006-01-05  30.882326  319.608856   93.939911  24.174795  32.301315  18.539701
# 2006-01-06  30.835981  319.608856   95.270950  24.345121  32.334446  18.648609
# 2006-01-09  30.855846  318.096863   96.417076  24.740532  32.676727  18.645660
# ...               ...         ...         ...        ...        ...        ...
# 2015-12-24  14.103423   40.187351  150.992554  51.625504  24.987900  42.026825
# 2015-12-28  13.989092   39.935757  150.289139  51.454983  24.749409  41.919491
# 2015-12-29  14.111584   40.393208  151.869675  51.989838  25.041752  42.387138
# 2015-12-30  13.923758   39.874756  150.611862  51.617760  24.795572  42.080486
# 2015-12-31  13.744097   39.455421  149.138992  51.183681  24.472456  41.674164
#
# [2517 rows x 6 columns]

# %%
df.xs(key = 'Close', axis=1).max()
# Out:
# Stock Info
# BAC     37.699574
# C      386.292755
# GS     186.076096
# JPM     53.933922
# MS      50.462799
# WFC     44.268097
# dtype: float64

# %%
returns = pd.DataFrame()    #Initialize an empty DataFrame for storing returns

# %%
for tick in tickers:
    returns[tick+ ' Return'] = df['Close'][tick].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013813   -0.005772   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001026    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
sns.set_style(style='darkgrid')
sns.pairplot(returns[1:])

# %% [markdown]
# ### Using this return DataFRame, figure out on what dates each bank stock had the best and worst single day returns.

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ### Take a look at the SD of the returns, which stock would you classify as the riskiest over the entire time period ? Which stock would you classify as the riskiest for the year 2015?

# %%
returns.std()
# Out:
# BAC Return    0.036659
# C Return      0.038672
# GS Return     0.025386
# JPM Return    0.027675
# MS Return     0.037717
# WFC Return    0.030195
# dtype: float64

# %%
returns.loc['2015-01-01': '2015-12-31'].std()
# Out:
# BAC Return    0.016174
# C Return      0.015288
# GS Return     0.014043
# JPM Return    0.014006
# MS Return     0.016287
# WFC Return    0.012552
# dtype: float64

# %% [markdown]
# ### Create a displot using seaborn of the 2015 returns for Morgan Stanley?

# %%
sns.displot(returns.loc['2015-01-01': '2015-12-31']['MS Return'],color='green',bins=50,kde=True)

# %% [markdown]
# ### Create a distplot using seaborn of the 2008 returns for CitiGroup?

# %%
sns.distplot(returns.loc['2008-01-01': '2008-12-31']['C Return'],color='red', bins=50)

#SD of Citigroup is 0.6 which is 10 times more than the Morgan Stanley 0.06
# Out:
# <AxesSubplot:xlabel='C Return', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style(style='whitegrid')
# %matplotlib inline

import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %% [markdown]
# ### Create a lineplot showing Closing price for each bank for the entire index of time.(Try using a for loop, or use.xs to get a cross section of the data)

# %%
plt.figure(figsize=(12, 4))
for tick in tickers:
    plt.plot(df['Close'][tick], label=tick)
plt.legend()

# %%
df.xs(key ='Close', axis=1).plot()
# Out:
# <AxesSubplot:xlabel='Date'>
